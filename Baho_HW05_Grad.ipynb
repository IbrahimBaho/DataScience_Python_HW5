# %% [markdown]
# Graduate Students Only: Use the dataset provided (gapminder_lifeExp_gdp) to reproduce the following plots. Use numpy and matplotlib.pyplot. First, remove all entries for Oceania. You may use the following structured data type: dt = {'names':('country', 'year', 'pop', 'continent', 'lifeExp', 'gdp'), 'formats':('U25',np.int16, np.float, 'U10', np.float, np.float)}

# %%
import numpy as np
import matplotlib.pyplot as plt

dt = {'names':('country', 'year','pop','continent','lifeEx','gdp'),
     'formats': ('U25', np.int16, np.float, 'U10', np.float, np.float)}

path = input("Enter the Path/file: ")
npdata = np.loadtxt(path, skiprows=1, dtype=dt, delimiter=',')
      
Oceania = np.where(npdata['continent']=='Oceania')
npdata = np.delete(npdata,Oceania)
# Out:
# Enter the Path/file: hi

# %% [markdown]
# a) (20 points) Stacked bar chart and a pie chart (as subplots) for world population

# %%
Asia = []; Europ = []; Africa = [] ; America = []

asia_1952 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Asia')]['pop']))
asia_1957 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Asia')]['pop']))
asia_1962 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Asia')]['pop']))
asia_1967 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Asia')]['pop']))
asia_1972 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Asia')]['pop']))
asia_1977 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Asia')]['pop']))
asia_1982 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Asia')]['pop']))
asia_1987 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Asia')]['pop']))
asia_1992 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Asia')]['pop']))
asia_1997 = Asia.append(sum(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Asia')]['pop']))
asia_2002 = Asia.append(sum(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Asia')]['pop']))
asia_2007 = Asia.append(sum(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Asia')]['pop']))

europ_1952 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Europe')]['pop']))
europ_1957 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Europe')]['pop']))
europ_1962 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Europe')]['pop']))
europ_1967 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Europe')]['pop']))
europ_1972 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Europe')]['pop']))
europ_1977 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Europe')]['pop']))
europ_1982 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Europe')]['pop']))
europ_1987 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Europe')]['pop']))
europ_1992 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Europe')]['pop']))
europ_1997 = Europ.append(sum(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Europe')]['pop']))
europ_2002 = Europ.append(sum(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Europe')]['pop']))
europ_2007 = Europ.append(sum(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Europe')]['pop']))

africa_1952 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Africa')]['pop']))
africa_1957 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Africa')]['pop']))
africa_1962 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Africa')]['pop']))
africa_1967 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Africa')]['pop']))
africa_1972 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Africa')]['pop']))
africa_1977 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Africa')]['pop']))
africa_1982 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Africa')]['pop']))
africa_1987 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Africa')]['pop']))
africa_1992 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Africa')]['pop']))
africa_1997 = Africa.append(sum(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Africa')]['pop']))
africa_2002 = Africa.append(sum(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Africa')]['pop']))
africa_2007 = Africa.append(sum(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Africa')]['pop']))

america_1952 = America.append(sum(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Americas')]['pop']))
america_1957 = America.append(sum(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Americas')]['pop']))
america_1962 = America.append(sum(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Americas')]['pop']))
america_1967 = America.append(sum(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Americas')]['pop']))
america_1972 = America.append(sum(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Americas')]['pop']))
america_1977 = America.append(sum(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Americas')]['pop']))
america_1982 = America.append(sum(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Americas')]['pop']))
america_1987 = America.append(sum(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Americas')]['pop']))
america_1992 = America.append(sum(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Americas')]['pop']))
america_1997 = America.append(sum(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Americas')]['pop']))
america_2002 = America.append(sum(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Americas')]['pop']))
america_2007 = America.append(sum(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Americas')]['pop']))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2 ,figsize=(18,6))

width = 0.6
ind = np.arange(13)
xco = ['1952','1957','1962','1967','1972','1977','1982','1987','1992','1997','2002','2007']
ax1.bar(xco, Asia, width, align='center',color='b')
ax1.bar(xco, Africa, width, align='center',color= 'orange', bottom=Asia)
ax1.bar(xco, Europ, width, align='center',color= 'g', bottom=[i+j for i,j in zip(Asia, Africa)])
ax1.bar(xco, America, width, align='center',color= 'r', bottom=[i+j+k for i,j,k in zip(Asia, Africa,Europ)])
ax1.set_xticks(xco)
plt.setp(ax1.get_xticklabels(), rotation=45)
ax1.set_title('World Population', fontsize=16)
ax1.set_ylabel('Population - Billions', fontsize=14)
ax1.set_xlabel('Year', fontsize=14)
ax1.legend(('Asia', 'Africa', 'Europe', 'America'), fontsize=10, fancybox=True)

labels = ['Asia', 'Africa', 'Europe', 'America']
cont = [Asia[11], Africa[11], Europ[11], America[11]]
explode = (0.1, 0.075, 0.075, 0.075) 
ax2.set_title('Population - 2007', fontsize=16)
ax2.pie(cont , explode=explode, labels=labels, autopct='%.1f%%', shadow=True)
plt.show()

# %% [markdown]
# b) (15 points) Mean of life expectancy over years in each continent

# %%
years = [1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007]
Asia = []; Europ = []; Africa = [] ; America = []

asia_1952 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Asia')]['lifeEx']))
asia_1957 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Asia')]['lifeEx']))
asia_1962 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Asia')]['lifeEx']))
asia_1967 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Asia')]['lifeEx']))
asia_1972 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Asia')]['lifeEx']))
asia_1977 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Asia')]['lifeEx']))
asia_1982 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Asia')]['lifeEx']))
asia_1987 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Asia')]['lifeEx']))
asia_1992 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Asia')]['lifeEx']))
asia_1997 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Asia')]['lifeEx']))
asia_2002 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Asia')]['lifeEx']))
asia_2007 = Asia.append(np.mean(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Asia')]['lifeEx']))

europ_1952 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Europe')]['lifeEx']))
europ_1957 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Europe')]['lifeEx']))
europ_1962 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Europe')]['lifeEx']))
europ_1967 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Europe')]['lifeEx']))
europ_1972 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Europe')]['lifeEx']))
europ_1977 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Europe')]['lifeEx']))
europ_1982 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Europe')]['lifeEx']))
europ_1987 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Europe')]['lifeEx']))
europ_1992 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Europe')]['lifeEx']))
europ_1997 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Europe')]['lifeEx']))
europ_2002 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Europe')]['lifeEx']))
europ_2007 = Europ.append(np.mean(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Europe')]['lifeEx']))

africa_1952 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Africa')]['lifeEx']))
africa_1957 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Africa')]['lifeEx']))
africa_1962 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Africa')]['lifeEx']))
africa_1967 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Africa')]['lifeEx']))
africa_1972 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Africa')]['lifeEx']))
africa_1977 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Africa')]['lifeEx']))
africa_1982 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Africa')]['lifeEx']))
africa_1987 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Africa')]['lifeEx']))
africa_1992 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Africa')]['lifeEx']))
africa_1997 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Africa')]['lifeEx']))
africa_2002 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Africa')]['lifeEx']))
africa_2007 = Africa.append(np.mean(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Africa')]['lifeEx']))

america_1952 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1952, npdata['continent']=='Americas')]['lifeEx']))
america_1957 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1957, npdata['continent']=='Americas')]['lifeEx']))
america_1962 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1962, npdata['continent']=='Americas')]['lifeEx']))
america_1967 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1967, npdata['continent']=='Americas')]['lifeEx']))
america_1972 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1972, npdata['continent']=='Americas')]['lifeEx']))
america_1977 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1977, npdata['continent']=='Americas')]['lifeEx']))
america_1982 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1982, npdata['continent']=='Americas')]['lifeEx']))
america_1987 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1987, npdata['continent']=='Americas')]['lifeEx']))
america_1992 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1992, npdata['continent']=='Americas')]['lifeEx']))
america_1997 = America.append(np.mean(npdata[np.logical_and(npdata['year']==1997, npdata['continent']=='Americas')]['lifeEx']))
america_2002 = America.append(np.mean(npdata[np.logical_and(npdata['year']==2002, npdata['continent']=='Americas')]['lifeEx']))
america_2007 = America.append(np.mean(npdata[np.logical_and(npdata['year']==2007, npdata['continent']=='Americas')]['lifeEx']))
fig = plt.figure(figsize=(8,6))
ind = np.arange(1952,2008,5)
xco = ['1952','1957','1962','1967','1972','1977','1982','1987','1992','1997','2002','2007']
plt.plot(years, Asia , color='b', label='Asia')
plt.plot(years, Europ, color='g', label='Europ')
plt.plot(years, Africa , color='orange', label='Africa')
plt.plot(years, America, color='r', label='America')
plt.annotate('Africa', xy = (1957,41), rotation=30)
plt.annotate('Asia', xy = (1954,47),rotation=33 )
plt.annotate('America', xy = (1953,55) , rotation=33)
plt.annotate('Europe', xy = (1955,66), rotation=30)

plt.xlabel('Year', fontsize=14)
plt.xticks(ind, xco, fontsize=10, rotation=45)
plt.ylabel('Life Expectancy (Mean)', fontsize=14)
plt.title('Life Expectancy - Trend')
plt.show()

# %% [markdown]
# c) (15 points) The trend of life expectancy over years for four countries (USA, Germany, Egypt, and China)

# %%
years = [1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007]

USA = npdata[npdata['country']=='United States']['lifeEx']
China = npdata[ npdata['country']=='China']['lifeEx']
Germany = npdata[npdata['country']=='Germany']['lifeEx']
Eygpt = npdata[npdata['country']=='Egypt']['lifeEx']

gs = plt.GridSpec(2,2, wspace=0.25, hspace=0.25)
fig = plt.figure(figsize=(9,9))
ax1 = plt.subplot(gs[0,0]) 
ax2 = plt.subplot(gs[0,1])  
ax3 = plt.subplot(gs[1,0])   
ax4 = plt.subplot(gs[1,1])   

ax1.plot(years, USA , 'ro-', label='USA')
ax1.set_title('USA')
ax1.set_xticks(years)
plt.setp(ax1.get_xticklabels(), rotation=45)

ax2.plot(years, Germany , 'go-', label='Germany')
ax2.set_ylabel('life Expectancy')
ax2.set_xticks(years)
plt.setp(ax2.get_xticklabels(), rotation=45)
ax2.set_title('Germany')

ax3.plot(years, Eygpt, 'yo-', label='Egypt')
ax3.set_xticks(years)
plt.setp(ax3.get_xticklabels(), rotation=45)
ax3.set_title('Egypt')

ax4.plot(years, China, 'bo-', label='China')
ax4.set_ylabel('life Expectancy')
ax4.set_xticks(years)
plt.setp(ax4.get_xticklabels(), rotation=45)
ax4.set_title('China')

plt.plot()
plt.show()
